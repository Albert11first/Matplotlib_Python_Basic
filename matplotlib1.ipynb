# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randn
import pandas as pd

# %%
my_df = pd.DataFrame(randn(25,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0   0.173319  0.318329  1.712726 -0.420165
# 1  -0.609661  0.647058 -0.127064 -0.173236
# 2   1.580722 -0.642539  0.222197 -0.655698
# 3  -0.641627 -1.402625  0.726117 -0.621481
# 4  -1.543463 -0.150763 -1.017258  0.719427
# 5   0.569541  0.963514  1.424538  0.147064
# 6   1.060812  0.152430 -1.325448 -0.686433
# 7  -0.535389  0.076498 -0.959864 -2.502816
# 8   2.500856 -1.320810 -0.663082  1.427763
# 9  -0.511797 -1.469794 -0.428779  1.210824
# 10 -0.388302  0.800639 -1.601623 -0.920102
# 11 -0.273147  0.472058  0.467178 -0.613788
# 12 -1.136614  1.885816  1.673414  0.821218
# 13 -0.520183 -0.103867 -0.552210 -1.154793
# 14  0.751966  1.240325  2.092209 -1.844257
# 15  0.661570 -0.385373 -0.438883  0.171194
# 16 -0.591559  0.408162  1.009811  0.946375
# 17  2.343844  0.090749  0.932766  0.623963
# 18 -0.620885  0.087061 -0.042566 -0.495773
# 19 -0.533654 -1.289392 -1.380885 -0.544460
# 20  1.445378  1.339324 -0.048796  0.436309
# ...

# %%
# histogram 
my_df['Wed'].hist(bins = 10, grid=False, legend=True)
# Out:
# <Axes: >

# %%
my_df['Wed'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# area plot
my_df.plot(kind = 'area', stacked = False)
# Out:
# <Axes: >

# %%
my_df.abs().plot(kind = 'area', alpha = 0.2, title = "Albert's plot")
# Out:
# <Axes: title={'center': "Albert's plot"}>

# %%
my_df['Mon'].abs().plot(kind = 'area', alpha = 0.2, title = "Albert's plot")
# Out:
# <Axes: title={'center': "Albert's plot"}>

# %%
plt.plot(np.random.randn(50),'k--')

# %%
! pip install pyabf
# Out:
# ...
#   Using cached pyabf-2.3.7-py3-none-any.whl (53 kB)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# BASIC DIAGRAM
x = np.linspace(-1, 2, 50)  # ndArray
y = 2 * x + 1
y1 = x ** 2

plt.figure(num=0, figsize=(8, 5))
plt.plot(x,y1)
plt.plot(x, y,color = 'red',linewidth = 1,linestyle = '--')

# %%
# SET RANGE
# SET LABEL
plt.xlim((-1,2))
plt.ylim((-2,3))
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
# SET TICKS
new_ticks = np.linspace(-1,2,5)
plt.xticks(new_ticks)

plt.yticks([-2,-1.8,-1,1.22,3],
            [r'$really\ bad$',r'$bad\ \alpha$','normal','good',r'$excellent$'])
# Out:
# ([<matplotlib.axis.YTick at 0x1d8d2bfea10>,
# ...
#  [Text(0, -2.0, '$really\\ bad$'),
#   Text(0, -1.8, '$bad\\ \\alpha$'),
#   Text(0, -1.0, 'normal'),
#   Text(0, 1.22, 'good'),
#   Text(0, 3.0, '$excellent$')])

# %%
# SET THE LOCATION OF AXIS 
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

# %%
# SET LEGEND
l1, = plt.plot(x,y1)
l2, = plt.plot(x, y,color = 'red',linewidth = 1,linestyle = '--')
# legend()
plt.legend(handles = [l1,l2],labels = ['aaa','bbb'],loc = 'best')
plt.show()

# %%
x = np.linspace(-1, 2, 50)  # ndArray
y = 2 * x + 1
y1 = x ** 2

# figure 1
plt.figure(num=0, figsize=(8, 5))
#plt.plot(x,y1)
#plt.plot(x, y,color = 'red',linewidth = 1,linestyle = '--')
plt.xlim((-1,2))
plt.ylim((-2,3))
plt.xlabel('x axis')
plt.ylabel('y axis')

new_ticks = np.linspace(-1,2,5)
plt.xticks(new_ticks)

plt.yticks([-2,-1.8,-1,1.22,3],
            [r'$really\ bad$',r'$bad\ \alpha$','normal','good',r'$excellent$'])

# gca =  get current axis
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

l1, = plt.plot(x,y1)
l2, = plt.plot(x, y,color = 'red',linewidth = 1,linestyle = '--')
plt.legend(handles = [l1,l2],labels = ['aaa','bbb'],loc = 'best')
plt.show()
#

# %%
x = np.linspace(-1, 2, 50)  # ndArray
y = 2 * x + 1
y1 = x ** 2

# figure 1
plt.figure(num=0, figsize=(8, 5))
plt.plot(x,y1)
plt.plot(x, y,color = 'red',linewidth = 1,linestyle = '--')
plt.xlim((-1,2))
plt.ylim((-2,3))
plt.xlabel('x axis')
plt.ylabel('y axis')

new_ticks = np.linspace(-1,2,5)
plt.xticks(new_ticks)

plt.yticks([-2,-1.8,-1,1.22,3],
            [r'$really\ bad$',r'$bad\ \alpha$','normal','good',r'$excellent$'])

# gca =  get current axis
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

x0 = 0.6
y0 = 2*x0 +1 
# plot a single point
plt.scatter(x0,y0,s=50,color='b')
# plot a dotted line 
plt.plot([x0,x0],[y0,0],'k--',lw='2')


# add annotation
#annotation method 1 
plt.annotate(r'$2x+1=%s$'%y0,xy=(x0,y0),xycoords='data',xytext=(+3,-30),textcoords='offset points',
             fontsize=16,arrowprops=dict(arrowstyle='->',connectionstyle = 'arc3,rad=.2'))

# annotation method 2
plt.text(-0.5,1,r'$some text here $', fontdict={'size':16,'color':'r'})
# Out:
# Text(-0.5, 1, '$some text here $')

# %%
x = np.linspace(-1, 2, 50)  # ndArray
y = 2 * x + 1
y1 = x ** 2

# figure 1
plt.figure(num=0, figsize=(8, 5))
plt.plot(x,y1)
plt.plot(x, y,color = 'red',linewidth = 1,linestyle = '--')
plt.xlim((-1,2))
plt.ylim((-2,3))
plt.xlabel('x axis')
plt.ylabel('y axis')

new_ticks = np.linspace(-1,2,10)
plt.xticks(new_ticks)

plt.yticks([-2,-1.8,-1,1.22,3],
            [r'$really\ bad$',r'$bad\ \alpha$','normal','good',r'$excellent$'])

# gca =  get current axis
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor = 'yellow',edgecolor = 'red', alpha = 0.7)) # alpha : transperency
    
plt.show()

# %%
# scatter plot
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T = np.arctan2(Y,X) # for color 

plt.scatter(X,Y,s=75,c=T,alpha=0.5)
plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))
plt.xticks(())
plt.yticks(())
# plt.scatter(
#     x,
#     y,
#     s=None,
#     c=None,
#     marker=None,
#     cmap=None,
#     norm=None,
#     vmin=None,
#     vmax=None,
#     alpha=None,
#     linewidths=None,
#     *,
#     edgecolors=None,
#     plotnonfinite=False,
#     data=None,
#     **kwargs,
# )

plt.show()

# %%
n =20
X = np.arange(n)
Y1 = (1-X/float(n))*np.random.uniform(0.5,1.0,n)
Y2= (1-X/float(n))*np.random.uniform(0.5,1.0,n)

plt.figure(num=0, figsize=(16, 5))
plt.bar(X,+Y1,facecolor = '#113285',edgecolor = 'white')
plt.bar(X,-Y2,facecolor = '#a5dee4',edgecolor = 'white')

for x,y in zip(X,Y1): #把X,Y 的值传进 x,y中
    # ha = horizontal alignment 
    # va = vertical alignment
    plt.text(x,y+0.05,'%.2f'%y,ha='center',va = 'bottom')

for x,y in zip(X,Y2):
    plt.text(x,-y-0.05,'-%.2f'%y,ha='center',va = 'top')

plt.xlim((-.5,n))
plt.ylim((-1.25,1.25))
plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
n= 1000
x = np.linspace(-2,2,n)
y = np.linspace(-2,2,n)
def f(x,y):
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)
X,Y = np.meshgrid(x,y)

#  将 x,y 变成对应的坐标 X,Y
# plot the contour
C = plt.contour(X,Y,f(X,Y),20, colors = 'black',linewidth = 0.2)

# fill the contour 
plt.contourf(X,Y,f(X,Y),20,alpha = 0.5, cmap = plt.cm.hot)

# add label
plt.clabel(C,inline = True,fontsize = 10)
# Out:
# C:\Users\18305\AppData\Local\Temp\ipykernel_9192\2833742450.py:10: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   C = plt.contour(X,Y,f(X,Y),20, colors = 'black',linewidth = 0.2)
# <a list of 24 text.Text objects>

# %%
a = np.random.randn(25).reshape(5,5)

plt.imshow(a,interpolation='nearest',cmap = 'bone',origin='upper')
plt.colorbar(shrink=0.9)

plt.xticks(())
plt.yticks(())
# Out:
# ([], [])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X ** 2 + Y ** 2)

Z = np.sin(R)
fig.add_axes(ax)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, edgecolor = 'black',cmap=plt.get_cmap('rainbow'))
ax.contourf(X,Y,Z,zdir='z',offset=-1,cmap='rainbow')
plt.show()

# %%
# SUBPLOT
x = np.linspace(-1, 2, 50)  # ndArray
y = 2 * x + 1
y1 = x ** 2
y2 = np.sin(x**2+y**4)
y3 = np.sqrt(x**2+y**2)

plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.plot(x,y1)

plt.subplot(2,2,3)
plt.plot(x,y2)

plt.subplot(224)
plt.plot(x,y3)
plt.show()

# %%
x = np.linspace(-1, 2, 50)  # ndArray
y = 2 * x + 1
y1 = x ** 2
y2 = np.sin(x**2+y**4)
y3 = np.sqrt(x**2+y**2)
y4 = np.tan(2**x+y**2)

plt.figure()
plt.subplot(2,1,1)     # 2 rows, 3 cols into 1, number 1
plt.plot(x,y)

plt.subplot(2,3,4)
plt.plot(x,y1)

plt.subplot(2,3,5)
plt.plot(x,y2)

plt.subplot(2,3,6)
plt.plot(x,y3)

plt.show()

# %%
import matplotlib.gridspec as gridspec

plt.figure()

# method 1 
# subplot2grid
plt.figure()
ax1 = plt.subplot2grid((3,3),(0,0),colspan=3,rowspan=1) # 第一个框的起点为00，占3列，1行
ax1.plot(x,y2)
ax1.set_title('ax1:y2')

ax2 = plt.subplot2grid((3,3),(1,0),colspan=2)
ax2.plot(x,y1)

ax3 = plt.subplot2grid((3,3),(1,2),colspan=1,rowspan=2)
ax3.plot(x,y)

ax4 = plt.subplot2grid((3,3),(2,0),colspan=2)
ax4.plot(x,y4)


plt.tight_layout()

plt.show()
